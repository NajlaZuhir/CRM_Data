# %% [markdown]
# <a href="https://colab.research.google.com/github/NajlaZuhir/CRM_Data/blob/main/synthetic_fake.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Generating Data USing Faker

# %%
# !pip install faker
# from transliterate import translit
# !pip install googletrans==4.0.0-rc1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 16.1 MB/s eta 0:00:00
# ...

# %%
from faker import Faker
import pandas as pd
import random
from datetime import datetime  # Import datetime class specifically

# %%
jobs = ['Engineer', 'Teacher', 'Doctor', 'Business Owner', 'Student', 'Nurse', "Other"]
cities_in_qatar = ["Doha","Al Wakrah","Al Khor","Umm Salal Mohammed","Al Rayyan","Al Daayen","Madinat ash Shamal"]
list_cuisines = ["Italian", "Japanese", "Mexican", "Indian", "French", "Chinese", "Thai", "Arabic", "Other", 'Italian',
 'French',
 'Chinese',
 'Japanese',
 'Mexican',
 'Thai',
 'Indian',
 'Spanish',
 'Greek',
 'Turkish',
 'Moroccan',
 'Vietnamese',
 'Korean',
 'Brazilian',
 'Ethiopian',
 'Lebanese',
 'Peruvian',
 'American',
 'Caribbean',
 'Russian',
 'Egyptian',
 'South African',
 'Malaysian',
 'Cuban',
 'Argentinian',
 'Portuguese',
 'Filipino',
 'Indonesian',
 'Belgian',
 'Swedish']

attractions_in_qatar = ["The Pearl-Qatar","Souq Waqif","Museum of Islamic Art","Katara Cultural Village","Aspire Park",
    "Al Zubarah Fort and Archaeological Site","Doha Corniche","Sheikh Faisal Bin Qassim Al Thani Museum",
    "Katara Beach","Qatar National Museum", "Other"]

event_types = ["Festival","Concert","Exhibition","Football event","Championship event","Doha Expo","Workshop",
    "Doha Tour","Marathon", "Other"]

fake_hobbies = ["Reading","Traveling","Photography","Painting","Cooking","Gardening","Playing musical instruments",
    "Hiking","Swimming","Cycling",'Hiking',
 'Photography',
 'Snorkeling',
 'Scuba Diving',
 'Bird Watching',
 'Cycling',
 'Kayaking',
 'Surfing',
 'Skiing/Snowboarding',
 'Camping',
 'Golfing',
 'Fishing',
 'Rock Climbing',
 'Sailing',
 'Hot Air Ballooning',
 'Wine Tasting',
 'Food Tours',
 'Museum Visits',
 'Historical Site Exploration',
 'City Tours',
 'Shopping',
 'Spa and Wellness',
 'Yoga Retreats',
 'Art Workshops',
 'Cooking Classes',
 'Language Learning',
 'Dancing',
 'Music Festivals',
 'Theater Performances',
 'Volunteering']

# %%
# List of feedbacks
# Updated list of feedbacks
feedbacks_list = [
    # Positive Comments
    "Absolutely mesmerized by Qatar's modern architecture and vibrant culture!",
    "The hospitality in Qatar is unparalleled, making my stay truly memorable.",
    "Qatar's rich history comes alive through its museums and heritage sites. A must-visit for history enthusiasts!",
    "The cleanliness and well-maintained infrastructure make Qatar a pleasure to explore.",
    "Incredible shopping experience with a perfect blend of traditional markets and luxury malls.",
    "The cuisine in Qatar is a delightful fusion of flavors, satisfying even the most discerning foodies.",
    "Qatar's commitment to sustainable tourism is commendable – eco-friendly initiatives are evident everywhere.",
    "The warmth and friendliness of the locals create a welcoming atmosphere for tourists.",
    "Qatar's safety measures are top-notch, ensuring a worry-free and secure travel experience.",
    "The desert safari was a thrilling adventure, offering breathtaking views of the dunes.",

    # Negative Comments
    "Traffic congestion in some areas can be frustrating, impacting the overall travel experience.",
    "While the modern side is impressive, the preservation of traditional areas could be better.",
    "Prices in Qatar, especially in tourist areas, can be on the higher side, making it less budget-friendly.",
    "Limited public transportation options make getting around a bit challenging at times.",
    "Some attractions were overcrowded, detracting from the expected tranquility.",
    "Despite efforts, communication in English can be a barrier in certain non-touristy areas.",
    "The weather can be extremely hot, making outdoor activities uncomfortable during certain months.",
    "Lack of clear signage in certain places made navigation confusing for tourists.",
    "Diversity in dining options could be improved, especially for those with specific dietary requirements.",
    "The cultural dress code may be restrictive for some visitors, impacting their comfort.",

    # Neutral Comments
    "The blend of modernity and tradition in Qatar offers a unique and diverse experience for tourists.",
    "The local transportation system is efficient, but improvements could enhance the overall convenience.",
    "Tourist attractions in Qatar cater to a wide range of interests, providing something for everyone.",
    "The variety of accommodations caters to different preferences, from luxury hotels to budget-friendly options.",
    "Qatar's efforts to promote cultural events and festivals add vibrancy to the tourist experience.",
    "Certain areas may lack the hustle and bustle typically associated with tourist destinations.",
    "The availability of information in multiple languages is helpful for international visitors.",
    "Tourist guides play a crucial role in enhancing the understanding of Qatar's history and culture.",
    "The ease of obtaining necessary permits for specific activities contributes to a smooth travel experience.",
    "Local markets offer authentic products, but bargaining skills may come in handy for a better deal."
]

# %% [markdown]
# ### Dataframe
#
# We have added some new columms

# %%
fake = Faker()
start_id = 1001
reservation_id = 1

data = []

for i in range(100):
    record = {
        # identification
        "Tourist_ID": start_id,
        "Reservation_ID": reservation_id,
        "passport_number" : fake.random_int(min=100000000, max=999999999),

        # personal info
        "Name": fake.name(),
        "Age": fake.random_int(18, 80),
        "Gender": fake.random_element(elements=('Male', 'Female')),
        "phone_number": fake.phone_number(),
        "Nationality": fake.country(),
        'Nationality_group': random.choice(['GCC', 'Other Arab', 'Other Africa', 'Other Asia inc. Oceania', 'Europe', 'Americans']),
        'family_size': fake.random_int(min=1, max=8),
        'health_insurance': random.choice(['Yes', 'No']),

        # Date
        'Date_Of_Reservation' : fake.date_between(start_date='-5y', end_date='today'),
        'Date_Of_arival' : fake.date_between(start_date='-5y', end_date='today'),
        'arrival_month': fake.month(),


        # Address info
        'country_address': fake.country(),
        'street_address': fake.street_address(),
        'zipcode': fake.zipcode(),
        'state': fake.state(),
        'city': fake.city(),

        # Occupation and financial info
        "Occupation": fake.random_element(elements=jobs),
        'annual_income': fake.random_int(min=20000, max=150000),

        # personal preferences
        "Hobby": fake.random_element(elements=fake_hobbies),
        'payment_preferences': random.choice(['Credit Card', 'PayPal', 'Bank Transfer']),
        "Best_Attraction": fake.random_element(elements=attractions_in_qatar),
        "Cuisine": fake.random_element(elements=list_cuisines),

        # Travel and Transportation info
        "Preferred_Travel_Seasons": fake.random_element(elements=('Spring', 'Summer', 'Autumn', 'Winter')),
        "Modes_of_Travel": fake.random_element(elements=('Sea', 'Land', 'Air')),
        "Frequency_of_Travel": fake.random_element(elements=('Frequent', 'Occasional', 'Rare')),
        "Transportation_Mode": fake.random_element(elements=('Car', 'Bus', 'Metro')),

        # Visit info
        "Num_of_Visits": fake.random_int(min=1, max=7),
        "Days_of_Stay": fake.random_int(5, 60),
        "Event_Type": fake.random_element(elements=event_types),

        # Accommodation info
        "Room_Preferences": fake.random_element(elements=('Single', 'Double', 'Suite')),
        "Hotel_Type": fake.random_element(elements=('Luxury', 'Mid-Range', 'Budget')),
        "Location": fake.random_element(elements=cities_in_qatar),

        # Additional fields (agency concern related)

        "customer_tenure": None, # Placeholder for now
        "package_types": fake.random_element(elements=['Sightseeing Tours', 'Adventure Tours', 'Cultural Tours', 'Beach and Resort Tours', 'Luxury and VIP Tours']),
        "package_cost": None,  # Placeholder for now
        "package_price": None,  # Placeholder for now
        "profit": None,  # Placeholder for now

        # Engagement and feedback
        "Total_Spendings": fake.random_int(min=2000, max=30000),
        "Subscribed_to_Loyalty_Program": fake.boolean(),
        "Rating_of_Services": fake.random_int(min=1, max=5),
        "Feedback": fake.random_element(elements=feedbacks_list),

    }

    record["customer_tenure"] = (datetime.now() - pd.to_datetime(record['Date_Of_Reservation'])).days


    # Set package_cost and package_price based on the selected package_types
    if record["package_types"] == 'Sightseeing Tours':
        record["package_cost"] = 300
        record["package_price"] = 600
    elif record["package_types"] == 'Adventure Tours':
        record["package_cost"] = 500
        record["package_price"] = 1200
    elif record["package_types"] == 'Cultural Tours':
        record["package_cost"] = 400
        record["package_price"] = 800
    elif record["package_types"] == 'Beach and Resort Tours':
        record["package_cost"] = 800
        record["package_price"] = 1500
    elif record["package_types"] == 'Luxury and VIP Tours':
        record["package_cost"] = 1500
        record["package_price"] = 3000

    # Calculate profit (package_price - package_cost)
    record["profit"] = record["package_price"] - record["package_cost"]

    data.append(record)

    reservation_id += 1
    start_id += 1

# Create DataFrame
df = pd.DataFrame(data)

# Save to CSV file
df.to_csv("generated_data.csv", index=False)

# Display DataFrame
print(df.head())
# Out:
#    Tourist_ID  Reservation_ID  passport_number            Name  Age  Gender  \
# 0        1001               1        597569133  Charles Rivera   77    Male
# 1        1002               2        353306401    Sara Nichols   46  Female
# 2        1003               3        173240850    Diane Bryant   63  Female
# 3        1004               4        167563882  Jason Phillips   70    Male
# 4        1005               5        155208048  Kenneth Patton   78  Female
#
#              phone_number                                        Nationality  \
# 0            617.722.3389                                              Nauru
# 1       (663)661-8279x013                                             Monaco
# 2  001-899-816-9988x60915                                            Grenada
# 3            365.889.6355  British Indian Ocean Territory (Chagos Archipe...
# 4         +1-628-672-5330                                             Latvia
#
# ...

# %%
df.head()
# Out:
#    Tourist_ID  Reservation_ID  passport_number                Name  Age  \
# 0        1001               1        151188951  Gabrielle Lewis MD   56
# 1        1002               2        304438064       Lauren Guzman   65
# 2        1003               3        618275333       Lori Holloway   40
# 3        1004               4        832224491      Patricia Evans   79
# 4        1005               5        924740623       Tina Johnston   42
#
#    Gender            phone_number    Nationality Nationality_group  \
# 0    Male  001-324-562-8580x32296         Angola               GCC
# 1  Female            459.854.3871          Aruba               GCC
# 2  Female              9925070865          Spain      Other Africa
# 3    Male            732.832.1988       Portugal            Europe
# 4    Male           (772)265-6606  Guinea-Bissau         Americans
#
#    family_size  ...            Location customer_tenure  \
# 0            8  ...  Madinat ash Shamal            1570
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 44 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Tourist_ID                     100 non-null    int64
#  1   Reservation_ID                 100 non-null    int64
#  2   passport_number                100 non-null    int64
#  3   Name                           100 non-null    object
#  4   Age                            100 non-null    int64
#  5   Gender                         100 non-null    object
#  6   phone_number                   100 non-null    object
#  7   Nationality                    100 non-null    object
#  8   Nationality_group              100 non-null    object
#  9   family_size                    100 non-null    int64
#  10  health_insurance               100 non-null    object
#  11  Date_Of_Reservation            100 non-null    object
# ...
